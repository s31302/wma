# %% [markdown]
# Instrukcje
# Zaimplementuj, wytrenuj i przetestuj model sieci neuronowej do klasyfikacji obrazów z zestawu danych CIFAR-10. Zestaw danych składa się z 60 000 kolorowych obrazów (32×32 piksele) podzielonych na 10 klas, w tym samochody, psy, statki i inne.
#
# Wytyczne dotyczące modelu:
# - Użyj warstw Conv2D, Dropout, Dense, MaxPooling2D i Flatten.
# - Jeśli sieć zawiera więcej niż 10 warstw, użyj kernel_initializer, aby poprawić wydajność i zapobiec problemowi zanikającego gradientu.
#
# Kryteria oceny:
# Wydajność Twojego modelu będzie oceniana na podstawie końcowej dokładności danych testowych:
# - Dokładność < 0,599 → 0 punktów
# - 0,600 < Dokładność < 0,699 → 7 punktów
# - 0,700 < Dokładność > 0,779 → 9 punktów
# - 0,78 < Dokładność > 0,799 → 12 punktów
# - Dokładność > 0,800 → 14 punktów
#
# Wymagane wyniki (do uwzględnienia w raporcie):
# - Wizualizacja architektury sieciowej
# - Wyeksportowany plik modelu (`.keras`)
# - Macierz pomyłek
# - Wykres historii uczenia (krzywe dokładności/strat)
# - Końcowa dokładność danych testowych
# - Kod źródłowy
# Moja praca

# %%
from tensorflow.keras.datasets import cifar10

(x_train, y_train), (x_test, y_test)=cifar10.load_data()

print('Shape of x_train is {}'.format(x_train.shape))
print('Shape of x_test is {}'.format(x_test.shape))
print('Shape of y_train is {}'.format(y_train.shape))
print('Shape of y_test is {}'.format(y_test.shape))
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 198s 1us/step
# Shape of x_train is (50000, 32, 32, 3)
# Shape of x_test is (10000, 32, 32, 3)
# Shape of y_train is (50000, 1)
# Shape of y_test is (10000, 1)

# %% [markdown]
#  (50000, 32, 32, 3) -> Oznacza to 50 tysięcy obrazków, z których każdy ma 32x32 piksele, a każdy piksel ma 3 kolory (RGB).

# %%
from matplotlib import pyplot

for i in range(9):
	# define subplot
	pyplot.subplot(330 + 1 + i)
	# plot raw pixel data
	pyplot.imshow(x_train[i])
# show the figure
pyplot.show()

# %%
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical
from matplotlib import pyplot

def load_dataset():
    # 1. Ładowanie danych
    (trainX, trainY), (testX, testY) = cifar10.load_data()

    # 2. One-hot encoding (zamiana etykiet 0-9 na wektory binarne)
    trainY = to_categorical(trainY)
    testY = to_categorical(testY)

    return trainX, trainY, testX, testY

def prep_pixels(train, test):
    # Konwersja na liczby zmiennoprzecinkowe i normalizacja do zakresu 0-1
    train_norm = train.astype('float32') / 255.0
    test_norm = test.astype('float32') / 255.0
    return train_norm, test_norm

# Wywołanie funkcji
x_train, y_train, x_test, y_test = load_dataset()
x_train, x_test = prep_pixels(x_train, x_test)

print(f'Shape of x_train: {x_train.shape}')
print('Shape of y_train is {}'.format(y_train.shape))
# Out:
# Shape of x_train: (50000, 32, 32, 3)
# Shape of y_train is (50000, 10)

# %%
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout, BatchNormalization
from tensorflow.keras.optimizers import SGD
from matplotlib import pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import numpy as np

def load_dataset():
    (trainX, trainY), (testX, testY) = cifar10.load_data()
    trainY = to_categorical(trainY)
    testY = to_categorical(testY)
    return trainX, trainY, testX, testY

def prep_pixels(train, test):
    return train.astype('float32') / 255.0, test.astype('float32') / 255.0

def define_model():
    model = Sequential()

    init = 'he_uniform'

    # Blok 1
    model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer=init, padding='same', input_shape=(32, 32, 3)))
    model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer=init, padding='same'))
    model.add(MaxPooling2D((2, 2)))
    model.add(Dropout(0.2)) # Zapobieganie overfittingowi

    # Blok 2
    model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer=init, padding='same'))
    model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer=init, padding='same'))
    model.add(MaxPooling2D((2, 2)))
    model.add(Dropout(0.3))

    # Blok 3
    model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer=init, padding='same'))
    model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer=init, padding='same'))
    model.add(MaxPooling2D((2, 2)))
    model.add(Dropout(0.4))

    # Klasyfikator
    model.add(Flatten())
    model.add(Dense(128, activation='relu', kernel_initializer=init))
    model.add(Dropout(0.5))
    model.add(Dense(10, activation='softmax')) # 10 klas wyjściowych

    # Optymalizacja
    opt = SGD(learning_rate=0.001, momentum=0.9)
    model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
    return model

def run_test_harness():
    trainX, trainY, testX, testY = load_dataset()
    trainX, testX = prep_pixels(trainX, testX)

    model = define_model()

    #trenowanie
    history = model.fit(trainX, trainY, epochs=100, batch_size=64, validation_data=(testX, testY), verbose=1)

    #ocena
    _, acc = model.evaluate(testX, testY, verbose=0)
    print(f'> Finalna dokładność: {acc:.3f}')

    # Zapisywanie modelu
    model.save('final_model.keras')

    return model, history, testX, testY

# Wywołanie
model, history, testX, testY = run_test_harness()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 21s 16ms/step - accuracy: 0.1619 - loss: 2.2199 - val_accuracy: 0.2581 - val_loss: 2.0078
# Epoch 2/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.2619 - loss: 1.9588 - val_accuracy: 0.3448 - val_loss: 1.7600
# Epoch 3/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.3255 - loss: 1.7767 - val_accuracy: 0.3784 - val_loss: 1.6981
# Epoch 4/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.3718 - loss: 1.6666 - val_accuracy: 0.4149 - val_loss: 1.6084
# Epoch 5/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - accuracy: 0.4118 - loss: 1.5820 - val_accuracy: 0.4864 - val_loss: 1.4294
# Epoch 6/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.4399 - loss: 1.5107 - val_accuracy: 0.4918 - val_loss: 1.3916
# Epoch 7/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.4642 - loss: 1.4546 - val_accuracy: 0.5202 - val_loss: 1.3182
# Epoch 8/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.4835 - loss: 1.4071 - val_accuracy: 0.5468 - val_loss: 1.2459
# Epoch 9/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.5027 - loss: 1.3619 - val_accuracy: 0.5290 - val_loss: 1.2768
# Epoch 10/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.5213 - loss: 1.3161 - val_accuracy: 0.5771 - val_loss: 1.1806
# Epoch 11/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.5372 - loss: 1.2787 - val_accuracy: 0.5919 - val_loss: 1.1270
# Epoch 12/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.5531 - loss: 1.2416 - val_accuracy: 0.6062 - val_loss: 1.1077
# Epoch 13/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.5658 - loss: 1.2103 - val_accuracy: 0.6280 - val_loss: 1.0516
# Epoch 14/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.5814 - loss: 1.1677 - val_accuracy: 0.6347 - val_loss: 1.0260
# Epoch 15/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.5909 - loss: 1.1474 - val_accuracy: 0.6117 - val_loss: 1.0961
# Epoch 16/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.5995 - loss: 1.1227 - val_accuracy: 0.6443 - val_loss: 0.9956
# Epoch 17/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.6091 - loss: 1.0933 - val_accuracy: 0.6602 - val_loss: 0.9487
# Epoch 18/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.6206 - loss: 1.0649 - val_accuracy: 0.6696 - val_loss: 0.9379
# Epoch 19/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.6266 - loss: 1.0478 - val_accuracy: 0.6743 - val_loss: 0.9144
# Epoch 20/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.6339 - loss: 1.0275 - val_accuracy: 0.6872 - val_loss: 0.8913
# Epoch 21/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.6416 - loss: 1.0100 - val_accuracy: 0.6742 - val_loss: 0.9116
# Epoch 22/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.6479 - loss: 0.9883 - val_accuracy: 0.7015 - val_loss: 0.8501
# Epoch 23/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.6562 - loss: 0.9781 - val_accuracy: 0.6988 - val_loss: 0.8643
# Epoch 24/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.6636 - loss: 0.9558 - val_accuracy: 0.7009 - val_loss: 0.8492
# Epoch 25/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.6669 - loss: 0.9460 - val_accuracy: 0.6923 - val_loss: 0.8643
# Epoch 26/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.6717 - loss: 0.9316 - val_accuracy: 0.7151 - val_loss: 0.8058
# Epoch 27/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.6812 - loss: 0.9156 - val_accuracy: 0.7152 - val_loss: 0.8032
# Epoch 28/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.6839 - loss: 0.9033 - val_accuracy: 0.7268 - val_loss: 0.7741
# Epoch 29/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.6863 - loss: 0.8935 - val_accuracy: 0.7248 - val_loss: 0.7849
# Epoch 30/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.6914 - loss: 0.8765 - val_accuracy: 0.7196 - val_loss: 0.7920
# Epoch 31/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.6964 - loss: 0.8633 - val_accuracy: 0.7339 - val_loss: 0.7564
# Epoch 32/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - accuracy: 0.6982 - loss: 0.8559 - val_accuracy: 0.7365 - val_loss: 0.7495
# Epoch 33/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.7073 - loss: 0.8413 - val_accuracy: 0.7407 - val_loss: 0.7345
# Epoch 34/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.
# Epoch 72/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.7977 - loss: 0.5892 - val_accuracy: 0.8039 - val_loss: 0.5708
# Epoch 73/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.7971 - loss: 0.5874 - val_accuracy: 0.8095 - val_loss: 0.5515
# Epoch 74/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.7965 - loss: 0.5797 - val_accuracy: 0.8107 - val_loss: 0.5504
# Epoch 75/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.8010 - loss: 0.5716 - val_accuracy: 0.8086 - val_loss: 0.5556
# Epoch 76/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.7999 - loss: 0.5743 - val_accuracy: 0.8066 - val_loss: 0.5639
# Epoch 77/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.8028 - loss: 0.5679 - val_accuracy: 0.8013 - val_loss: 0.5764
# Epoch 78/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.8047 - loss: 0.5679 - val_accuracy: 0.8107 - val_loss: 0.5415
# Epoch 79/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.8051 - loss: 0.5574 - val_accuracy: 0.8114 - val_loss: 0.5567
# Epoch 80/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.8081 - loss: 0.5573 - val_accuracy: 0.8143 - val_loss: 0.5443
# Epoch 81/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.8085 - loss: 0.5538 - val_accuracy: 0.8150 - val_loss: 0.5410
# Epoch 82/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.8098 - loss: 0.5479 - val_accuracy: 0.8083 - val_loss: 0.5609
# Epoch 83/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.8123 - loss: 0.5396 - val_accuracy: 0.8177 - val_loss: 0.5396
# Epoch 84/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.8129 - loss: 0.5400 - val_accuracy: 0.8140 - val_loss: 0.5518
# Epoch 85/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.8126 - loss: 0.5363 - val_accuracy: 0.8157 - val_loss: 0.5394
# Epoch 86/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.8145 - loss: 0.5322 - val_accuracy: 0.8126 - val_loss: 0.5419
# Epoch 87/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.8149 - loss: 0.5350 - val_accuracy: 0.8190 - val_loss: 0.5367
# Epoch 88/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - accuracy: 0.8155 - loss: 0.5278 - val_accuracy: 0.8190 - val_loss: 0.5443
# Epoch 89/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.8171 - loss: 0.5251 - val_accuracy: 0.8205 - val_loss: 0.5328
# Epoch 90/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - accuracy: 0.8198 - loss: 0.5185 - val_accuracy: 0.8147 - val_loss: 0.5401
# Epoch 91/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.8189 - loss: 0.5217 - val_accuracy: 0.8261 - val_loss: 0.5172
# Epoch 92/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 11s 10ms/step - accuracy: 0.8216 - loss: 0.5171 - val_accuracy: 0.8246 - val_loss: 0.5196
# Epoch 93/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.8232 - loss: 0.5087 - val_accuracy: 0.8163 - val_loss: 0.5328
# Epoch 94/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.8225 - loss: 0.5084 - val_accuracy: 0.8203 - val_loss: 0.5368
# Epoch 95/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.8235 - loss: 0.5040 - val_accuracy: 0.8254 - val_loss: 0.5112
# Epoch 96/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.8257 - loss: 0.5043 - val_accuracy: 0.8198 - val_loss: 0.5271
# Epoch 97/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.8257 - loss: 0.5046 - val_accuracy: 0.8205 - val_loss: 0.5373
# Epoch 98/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.8246 - loss: 0.5019 - val_accuracy: 0.8279 - val_loss: 0.5111
# Epoch 99/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.8268 - loss: 0.4962 - val_accuracy: 0.8270 - val_loss: 0.5056
# Epoch 100/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.8286 - loss: 0.4934 - val_accuracy: 0.8280 - val_loss: 0.5169
# > Finalna dokładność: 0.828

# %%
def plot_history(history):
    plt.figure(figsize=(12, 4))

    # Wykres dokładności
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Trening')
    plt.plot(history.history['val_accuracy'], label='Test')
    plt.title('Dokładność modelu')
    plt.xlabel('Epoka')
    plt.ylabel('Accuracy')
    plt.legend()

    # Wykres straty
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Trening')
    plt.plot(history.history['val_loss'], label='Test')
    plt.title('Strata modelu')
    plt.xlabel('Epoka')
    plt.ylabel('Loss')
    plt.legend()

    plt.show()

plot_history(history)

# %%
y_pred = model.predict(testX)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = np.argmax(testY, axis=1)

classes = ['samolot', 'samochód', 'ptak', 'kot', 'jeleń', 'pies', 'żaba', 'koń', 'statek', 'ciężarówka']

plt.figure(figsize=(10, 8))
cm = confusion_matrix(y_true_classes, y_pred_classes)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=classes)
disp.plot(cmap=plt.cm.Blues, xticks_rotation='vertical')
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 32, 32, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 32, 32, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 16, 16, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 16, 16, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 8, 8, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 8, 8, 128)      │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       262,272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,101,142 (4.20 MB)
#  Trainable params: 550,570 (2.10 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 550,572 (2.10 MB)

# %%
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout, BatchNormalization
from tensorflow.keras.optimizers import SGD
from matplotlib import pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import numpy as np

def load_dataset():
    (trainX, trainY), (testX, testY) = cifar10.load_data()
    trainY = to_categorical(trainY)
    testY = to_categorical(testY)
    return trainX, trainY, testX, testY

def prep_pixels(train, test):
    return train.astype('float32') / 255.0, test.astype('float32') / 255.0

def define_model():
    model = Sequential()

    init = 'he_uniform'

    # Blok 1
    model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer=init, padding='same', input_shape=(32, 32, 3)))
    model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer=init, padding='same'))
    model.add(MaxPooling2D((2, 2)))
    model.add(Dropout(0.2)) # Zapobieganie overfittingowi

    # Blok 2
    model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer=init, padding='same'))
    model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer=init, padding='same'))
    model.add(MaxPooling2D((2, 2)))
    model.add(Dropout(0.3))

    # Blok 3
    model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer=init, padding='same'))
    model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer=init, padding='same'))
    model.add(MaxPooling2D((2, 2)))
    model.add(Dropout(0.4))

    # Klasyfikator
    model.add(Flatten())
    model.add(Dense(128, activation='relu', kernel_initializer=init))
    model.add(Dropout(0.5))
    model.add(Dense(10, activation='softmax')) # 10 klas wyjściowych

    #Adam optymalizacja
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

    return model

def run_test_harness():
    trainX, trainY, testX, testY = load_dataset()
    trainX, testX = prep_pixels(trainX, testX)

    model = define_model()

    history = model.fit(trainX, trainY, epochs=100, batch_size=64, validation_data=(testX, testY), verbose=1)

    _, acc = model.evaluate(testX, testY, verbose=0)
    print(f'> Finalna dokładność: {acc:.3f}')

    model.save('final_model_adam.keras')

    return model, history, testX, testY

# Wywołanie
model, history, testX, testY = run_test_harness()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 20s 16ms/step - accuracy: 0.3118 - loss: 1.8381 - val_accuracy: 0.4500 - val_loss: 1.5040
# Epoch 2/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.4895 - loss: 1.4013 - val_accuracy: 0.5768 - val_loss: 1.1854
# Epoch 3/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.5769 - loss: 1.1882 - val_accuracy: 0.6426 - val_loss: 0.9922
# Epoch 4/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.6254 - loss: 1.0647 - val_accuracy: 0.6803 - val_loss: 0.8976
# Epoch 5/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.6576 - loss: 0.9772 - val_accuracy: 0.7048 - val_loss: 0.8485
# Epoch 6/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.6816 - loss: 0.9106 - val_accuracy: 0.7126 - val_loss: 0.8190
# Epoch 7/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.6978 - loss: 0.8669 - val_accuracy: 0.7316 - val_loss: 0.7653
# Epoch 8/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.7156 - loss: 0.8203 - val_accuracy: 0.7449 - val_loss: 0.7433
# Epoch 9/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.7270 - loss: 0.7906 - val_accuracy: 0.7559 - val_loss: 0.7049
# Epoch 10/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.7386 - loss: 0.7572 - val_accuracy: 0.7631 - val_loss: 0.6936
# Epoch 11/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.7452 - loss: 0.7404 - val_accuracy: 0.7767 - val_loss: 0.6496
# Epoch 12/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.7558 - loss: 0.7085 - val_accuracy: 0.7580 - val_loss: 0.7101
# Epoch 13/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.7597 - loss: 0.6998 - val_accuracy: 0.7814 - val_loss: 0.6475
# Epoch 14/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.7659 - loss: 0.6815 - val_accuracy: 0.7854 - val_loss: 0.6497
# Epoch 15/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.7750 - loss: 0.6591 - val_accuracy: 0.7958 - val_loss: 0.6096
# Epoch 16/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.7777 - loss: 0.6475 - val_accuracy: 0.7849 - val_loss: 0.6403
# Epoch 17/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 11s 10ms/step - accuracy: 0.7824 - loss: 0.6325 - val_accuracy: 0.7716 - val_loss: 0.6973
# Epoch 18/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.7865 - loss: 0.6206 - val_accuracy: 0.7926 - val_loss: 0.6348
# Epoch 19/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.7877 - loss: 0.6112 - val_accuracy: 0.7918 - val_loss: 0.6201
# Epoch 20/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.7894 - loss: 0.6079 - val_accuracy: 0.7859 - val_loss: 0.6289
# Epoch 21/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.7967 - loss: 0.5906 - val_accuracy: 0.8008 - val_loss: 0.5991
# Epoch 22/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.7982 - loss: 0.5870 - val_accuracy: 0.8073 - val_loss: 0.5808
# Epoch 23/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.8002 - loss: 0.5790 - val_accuracy: 0.8080 - val_loss: 0.5880
# Epoch 24/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.8048 - loss: 0.5644 - val_accuracy: 0.8133 - val_loss: 0.5691
# Epoch 25/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.8067 - loss: 0.5612 - val_accuracy: 0.8067 - val_loss: 0.5742
# Epoch 26/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.8098 - loss: 0.5590 - val_accuracy: 0.7995 - val_loss: 0.6016
# Epoch 27/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.8100 - loss: 0.5543 - val_accuracy: 0.8082 - val_loss: 0.5800
# Epoch 28/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.8133 - loss: 0.5426 - val_accuracy: 0.8108 - val_loss: 0.5898
# Epoch 29/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.8138 - loss: 0.5434 - val_accuracy: 0.8059 - val_loss: 0.5832
# Epoch 30/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.8148 - loss: 0.5381 - val_accuracy: 0.8112 - val_loss: 0.5685
# Epoch 31/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - accuracy: 0.


# %%
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout, BatchNormalization
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from matplotlib import pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import numpy as np

def load_dataset():
    (trainX, trainY), (testX, testY) = cifar10.load_data()
    trainY = to_categorical(trainY)
    testY = to_categorical(testY)
    return trainX, trainY, testX, testY

def prep_pixels(train, test):
    return train.astype('float32') / 255.0, test.astype('float32') / 255.0

def define_model():
    model = Sequential()

    init = 'he_uniform'

    # Blok 1
    model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer=init, padding='same', input_shape=(32, 32, 3)))
    model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer=init, padding='same'))
    model.add(MaxPooling2D((2, 2)))
    model.add(Dropout(0.2)) # Zapobieganie overfittingowi

    # Blok 2
    model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer=init, padding='same'))
    model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer=init, padding='same'))
    model.add(MaxPooling2D((2, 2)))
    model.add(Dropout(0.3))

    # Blok 3
    model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer=init, padding='same'))
    model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer=init, padding='same'))
    model.add(MaxPooling2D((2, 2)))
    model.add(Dropout(0.4))

    # Klasyfikator
    model.add(Flatten())
    model.add(Dense(128, activation='relu', kernel_initializer=init))
    model.add(Dropout(0.5))
    model.add(Dense(10, activation='softmax')) # 10 klas wyjściowych

    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

    return model

def run_test_harness():
    trainX, trainY, testX, testY = load_dataset()
    trainX, testX = prep_pixels(trainX, testX)

    model = define_model()
    # argumentaacja z przesuwaniem i filpem
    datagen = ImageDataGenerator(width_shift_range=0.1, height_shift_range=0.1, horizontal_flip=True)
    it_train = datagen.flow(trainX, trainY, batch_size=64)
    steps = int(trainX.shape[0] / 64)

    history = model.fit(it_train, steps_per_epoch=steps, epochs=100, batch_size=64, validation_data=(testX, testY), verbose=1)

    _, acc = model.evaluate(testX, testY, verbose=0)
    print(f'> Finalna dokładność: {acc:.3f}')

    model.save('final_model_argumentacja.keras')

    return model, history, testX, testY

# Wywołanie
model, history, testX, testY = run_test_harness()
# Out:
# Epoch 1/100
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 45s 49ms/step - accuracy: 0.3109 - loss: 1.8348 - val_accuracy: 0.4795 - val_loss: 1.4243
# Epoch 2/100
#   1/781 ━━━━━━━━━━━━━━━━━━━━ 13s 17ms/step - accuracy: 0.5312 - loss: 1.4753
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/epoch_iterator.py:116: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.5312 - loss: 1.4753 - val_accuracy: 0.4827 - val_loss: 1.4007
# Epoch 3/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 31s 40ms/step - accuracy: 0.4728 - loss: 1.4477 - val_accuracy: 0.5770 - val_loss: 1.1659
# Epoch 4/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 766us/step - accuracy: 0.5312 - loss: 1.5147 - val_accuracy: 0.5694 - val_loss: 1.1809
# Epoch 5/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 32s 42ms/step - accuracy: 0.5501 - loss: 1.2621 - val_accuracy: 0.6128 - val_loss: 1.0838
# Epoch 6/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 788us/step - accuracy: 0.6250 - loss: 1.1165 - val_accuracy: 0.6168 - val_loss: 1.0714
# Epoch 7/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 31s 40ms/step - accuracy: 0.5969 - loss: 1.1399 - val_accuracy: 0.6780 - val_loss: 0.9178
# Epoch 8/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 769us/step - accuracy: 0.6875 - loss: 0.8440 - val_accuracy: 0.6714 - val_loss: 0.9373
# Epoch 9/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 42s 42ms/step - accuracy: 0.6268 - loss: 1.0617 - val_accuracy: 0.6803 - val_loss: 0.9127
# Epoch 10/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 763us/step - accuracy: 0.6562 - loss: 0.9414 - val_accuracy: 0.6904 - val_loss: 0.8804
# Epoch 11/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 40s 42ms/step - accuracy: 0.6521 - loss: 0.9999 - val_accuracy: 0.7008 - val_loss: 0.8771
# Epoch 12/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 753us/step - accuracy: 0.5938 - loss: 1.1641 - val_accuracy: 0.7008 - val_loss: 0.8690
# Epoch 13/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 32s 40ms/step - accuracy: 0.6683 - loss: 0.9581 - val_accuracy: 0.7319 - val_loss: 0.7720
# Epoch 14/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 928us/step - accuracy: 0.6562 - loss: 1.1611 - val_accuracy: 0.7298 - val_loss: 0.7753
# Epoch 15/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 41s 42ms/step - accuracy: 0.6813 - loss: 0.9260 - val_accuracy: 0.7293 - val_loss: 0.7898
# Epoch 16/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 789us/step - accuracy: 0.6250 - loss: 1.1240 - val_accuracy: 0.7292 - val_loss: 0.7998
# Epoch 17/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 41s 42ms/step - accuracy: 0.6903 - loss: 0.9001 - val_accuracy: 0.7275 - val_loss: 0.7869
# Epoch 18/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 763us/step - accuracy: 0.7344 - loss: 0.9227 - val_accuracy: 0.7294 - val_loss: 0.7834
# Epoch 19/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 33s 42ms/step - accuracy: 0.7018 - loss: 0.8719 - val_accuracy: 0.7484 - val_loss: 0.7362
# Epoch 20/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 758us/step - accuracy: 0
100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 33s 42ms/step - accuracy: 0.7824 - loss: 0.6435 - val_accuracy: 0.8000 - val_loss: 0.6106
# Epoch 82/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 796us/step - accuracy: 0.7344 - loss: 0.6849 - val_accuracy: 0.7994 - val_loss: 0.6151
# Epoch 83/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 39s 41ms/step - accuracy: 0.7833 - loss: 0.6455 - val_accuracy: 0.7928 - val_loss: 0.6547
# Epoch 84/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 818us/step - accuracy: 0.8125 - loss: 0.5674 - val_accuracy: 0.7954 - val_loss: 0.6473
# Epoch 85/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 33s 42ms/step - accuracy: 0.7848 - loss: 0.6442 - val_accuracy: 0.8056 - val_loss: 0.6213
# Epoch 86/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 811us/step - accuracy: 0.7656 - loss: 0.7031 - val_accuracy: 0.8035 - val_loss: 0.6225
# Epoch 87/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 32s 41ms/step - accuracy: 0.7851 - loss: 0.6408 - val_accuracy: 0.8092 - val_loss: 0.5935
# Epoch 88/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7500 - loss: 0.7931 - val_accuracy: 0.8105 - val_loss: 0.5899
# Epoch 89/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 32s 41ms/step - accuracy: 0.7857 - loss: 0.6411 - val_accuracy: 0.8187 - val_loss: 0.5679
# Epoch 90/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 803us/step - accuracy: 0.7969 - loss: 0.8005 - val_accuracy: 0.8190 - val_loss: 0.5689
# Epoch 91/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 41s 41ms/step - accuracy: 0.7848 - loss: 0.6406 - val_accuracy: 0.8084 - val_loss: 0.5990
# Epoch 92/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7188 - loss: 0.8308 - val_accuracy: 0.8078 - val_loss: 0.5977
# Epoch 93/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 32s 41ms/step - accuracy: 0.7856 - loss: 0.6386 - val_accuracy: 0.8200 - val_loss: 0.5473
# Epoch 94/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 779us/step - accuracy: 0.7031 - loss: 0.8132 - val_accuracy: 0.8197 - val_loss: 0.5472
# Epoch 95/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 34s 43ms/step - accuracy: 0.7867 - loss: 0.6378 - val_accuracy: 0.8077 - val_loss: 0.5968
# Epoch 96/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 824us/step - accuracy: 0.7969 - loss: 0.6501 - val_accuracy: 0.8094 - val_loss: 0.5887
# Epoch 97/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 32s 41ms/step - accuracy: 0.7852 - loss: 0.6338 - val_accuracy: 0.8067 - val_loss: 0.5863
# Epoch 98/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 893us/step - accuracy: 0.7656 - loss: 0.7450 - val_accuracy: 0.8082 - val_loss: 0.5789
# Epoch 99/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 33s 42ms/step - accuracy: 0.7877 - loss: 0.6289 - val_accuracy: 0.8067 - val_loss: 0.5995
# Epoch 100/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 773us/step - accuracy: 0.7500 - loss: 0.7067 - val_accuracy: 0.8054 - val_loss: 0.6092
# > Finalna dokładność: 0.805

# %%
def plot_history(history):
    plt.figure(figsize=(12, 4))

    # Wykres dokładności
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Trening')
    plt.plot(history.history['val_accuracy'], label='Test')
    plt.title('Dokładność modelu')
    plt.xlabel('Epoka')
    plt.ylabel('Accuracy')
    plt.legend()

    # Wykres straty
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Trening')
    plt.plot(history.history['val_loss'], label='Test')
    plt.title('Strata modelu')
    plt.xlabel('Epoka')
    plt.ylabel('Loss')
    plt.legend()

    plt.show()

plot_history(history)

# %%
y_pred = model.predict(testX)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = np.argmax(testY, axis=1)

classes = ['samolot', 'samochód', 'ptak', 'kot', 'jeleń', 'pies', 'żaba', 'koń', 'statek', 'ciężarówka']

plt.figure(figsize=(10, 8))
cm = confusion_matrix(y_true_classes, y_pred_classes)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=classes)
disp.plot(cmap=plt.cm.Blues, xticks_rotation='vertical')
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step

# %%
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_12 (Conv2D)              │ (None, 32, 32, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_13 (Conv2D)              │ (None, 32, 32, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_6 (MaxPooling2D)  │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_14 (Conv2D)              │ (None, 16, 16, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_15 (Conv2D)              │ (None, 16, 16, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_7 (MaxPooling2D)  │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_16 (Conv2D)              │ (None, 8, 8, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_17 (Conv2D)              │ (None, 8, 8, 128)      │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_8 (MaxPooling2D)  │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_2 (Flatten)             │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 128)            │       262,272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,651,712 (6.30 MB)
#  Trainable params: 550,570 (2.10 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 1,101,142 (4.20 MB)

# %%
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout, BatchNormalization
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from matplotlib import pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import numpy as np

def load_dataset():
    (trainX, trainY), (testX, testY) = cifar10.load_data()
    trainY = to_categorical(trainY)
    testY = to_categorical(testY)
    return trainX, trainY, testX, testY

def prep_pixels(train, test):
    return train.astype('float32') / 255.0, test.astype('float32') / 255.0

def define_model():
    model = Sequential()

    init = 'he_uniform'

    # Blok 1
    model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer=init, padding='same', input_shape=(32, 32, 3)))
    model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer=init, padding='same'))
    model.add(MaxPooling2D((2, 2)))
    model.add(Dropout(0.2)) # Zapobieganie overfittingowi

    # Blok 2
    model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer=init, padding='same'))
    model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer=init, padding='same'))
    model.add(MaxPooling2D((2, 2)))
    model.add(Dropout(0.3))

    # Blok 3
    model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer=init, padding='same'))
    model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer=init, padding='same'))
    model.add(MaxPooling2D((2, 2)))
    model.add(Dropout(0.4))

    # Klasyfikator
    model.add(Flatten())
    model.add(Dense(128, activation='relu', kernel_initializer=init))
    model.add(Dropout(0.5))
    model.add(Dense(10, activation='softmax')) # 10 klas wyjściowych


    opt = SGD(learning_rate=0.001, momentum=0.9)
    model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])

    return model

def run_test_harness():
    trainX, trainY, testX, testY = load_dataset()
    trainX, testX = prep_pixels(trainX, testX)

    model = define_model()

    #argumentacja
    datagen = ImageDataGenerator(width_shift_range=0.1, height_shift_range=0.1, horizontal_flip=True)
    it_train = datagen.flow(trainX, trainY, batch_size=64)
    steps = int(trainX.shape[0] / 64)

    history = model.fit(it_train, steps_per_epoch=steps, epochs=100, batch_size=64, validation_data=(testX, testY), verbose=1)

    _, acc = model.evaluate(testX, testY, verbose=0)
    print(f'> Finalna dokładność: {acc:.3f}')

    model.save('final_model_sgd_argumentacja.keras')

    return model, history, testX, testY

# Wywołanie
model, history, testX, testY = run_test_harness()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 309s 2us/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 47s 48ms/step - accuracy: 0.1333 - loss: 2.2834 - val_accuracy: 0.2358 - val_loss: 2.1290
# Epoch 2/100
#   1/781 ━━━━━━━━━━━━━━━━━━━━ 7s 10ms/step - accuracy: 0.2031 - loss: 2.1113
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/epoch_iterator.py:116: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 673us/step - accuracy: 0.2031 - loss: 2.1113 - val_accuracy: 0.2367 - val_loss: 2.1315
# Epoch 3/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 30s 39ms/step - accuracy: 0.2216 - loss: 2.0743 - val_accuracy: 0.3175 - val_loss: 1.9306
# Epoch 4/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 781us/step - accuracy: 0.2031 - loss: 1.9634 - val_accuracy: 0.3125 - val_loss: 1.9321
# Epoch 5/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 31s 39ms/step - accuracy: 0.2811 - loss: 1.9264 - val_accuracy: 0.3470 - val_loss: 1.7930
# Epoch 6/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 767us/step - accuracy: 0.2656 - loss: 1.8406 - val_accuracy: 0.3449 - val_loss: 1.7950
# Epoch 7/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 31s 39ms/step - accuracy: 0.3227 - loss: 1.8004 - val_accuracy: 0.3988 - val_loss: 1.6530
# Epoch 8/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 777us/step - accuracy: 0.3281 - loss: 1.7187 - val_accuracy: 0.4020 - val_loss: 1.6496
# Epoch 9/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 32s 41ms/step - accuracy: 0.3602 - loss: 1.7039 - val_accuracy: 0.4275 - val_loss: 1.5563
# Epoch 10/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 824us/step - accuracy: 0.3906 - loss: 1.6215 - val_accuracy: 0.4265 - val_loss: 1.5583
# Epoch 11/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 31s 39ms/step - accuracy: 0.3895 - loss: 1.6380 - val_accuracy: 0.4625 - val_loss: 1.4890
# Epoch 12/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 770us/step - accuracy: 0.3906 - loss: 1.7197 - val_accuracy: 0.4632 - val_loss: 1.4828
# Epoch 13/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 31s 40ms/step - accuracy: 0.4084 - loss: 1.5923 - val_accuracy: 0.4804 - val_loss: 1.4245
# Epoch 14/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 760us/step - accuracy: 0.3750 - loss: 1.6811 - val_accuracy: 0.4783 - val_loss: 1.4275
# Epoch 15/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 31s 40ms/step - accuracy: 0.4264 - loss: 1.5498 - val_accuracy: 0.4827 - val_loss: 1.4115
# Epoch 16/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 863us/step - accuracy: 0.3750 - loss: 1.6388 - val_accuracy: 0.4917 - val_loss: 1.3898
# Epoch 17/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 33s 43ms/step - accuracy: 0.4476 - loss: 1.5036 - val_accuracy: 0.5303 - val_loss: 1.2933
# Epoch 18/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 776us/step - accuracy: 0.3281 - loss: 1.6312 - val_accuracy: 0.5311 - val_loss: 1.2856
# Epoch 19/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 31s 40ms/step - accuracy: 0.4598 - loss: 1.4718 - val_accuracy: 0.4997 - val_loss: 1.3417
# Epoch 20/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.4219 - loss: 1.4647 - val_accuracy: 0.4991 - val_loss: 1.3427
# Epoch 21/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 31s 40ms/step - accuracy: 0.4764 - loss: 1.4346 - val_accuracy: 0.5527 - val_loss: 1.2502
# Epoch 22/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 801us/step - accuracy: 0.7031 - loss: 1.2786 - val_accuracy: 0.5514 - val_loss: 1.2555
# Epoch 23/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 32s 40ms/step - accuracy: 0.4947 - loss: 1.3953 - val_accuracy: 0.5367 - val_loss: 1.2537
# Epoch 24/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.5156 - loss: 1.2117 - val_accuracy: 0.5333 - val_loss: 1.2625
# Epoch 25/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 31s 39ms/step - accuracy: 0.5055 - loss: 1.3698 - val_accuracy: 0.5437 - val_loss: 1.2515
# Epoch 26/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 779us/step - accuracy: 0
100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 39s 42ms/step - accuracy: 0.6859 - loss: 0.8982 - val_accuracy: 0.7345 - val_loss: 0.7523
# Epoch 88/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 780us/step - accuracy: 0.7344 - loss: 0.8806 - val_accuracy: 0.7372 - val_loss: 0.7492
# Epoch 89/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 33s 42ms/step - accuracy: 0.6890 - loss: 0.8873 - val_accuracy: 0.7214 - val_loss: 0.8014
# Epoch 90/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7031 - loss: 0.8489 - val_accuracy: 0.7230 - val_loss: 0.7954
# Epoch 91/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 32s 42ms/step - accuracy: 0.6960 - loss: 0.8799 - val_accuracy: 0.7375 - val_loss: 0.7534
# Epoch 92/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 779us/step - accuracy: 0.7969 - loss: 0.5955 - val_accuracy: 0.7370 - val_loss: 0.7564
# Epoch 93/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 32s 42ms/step - accuracy: 0.6956 - loss: 0.8695 - val_accuracy: 0.7171 - val_loss: 0.7970
# Epoch 94/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 827us/step - accuracy: 0.7812 - loss: 0.7154 - val_accuracy: 0.7126 - val_loss: 0.8058
# Epoch 95/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 32s 41ms/step - accuracy: 0.7016 - loss: 0.8658 - val_accuracy: 0.7269 - val_loss: 0.7695
# Epoch 96/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 745us/step - accuracy: 0.6562 - loss: 0.8900 - val_accuracy: 0.7318 - val_loss: 0.7572
# Epoch 97/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 32s 41ms/step - accuracy: 0.7029 - loss: 0.8529 - val_accuracy: 0.7381 - val_loss: 0.7366
# Epoch 98/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 748us/step - accuracy: 0.7188 - loss: 0.7748 - val_accuracy: 0.7328 - val_loss: 0.7482
# Epoch 99/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 31s 40ms/step - accuracy: 0.7051 - loss: 0.8502 - val_accuracy: 0.7404 - val_loss: 0.7462
# Epoch 100/100
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 774us/step - accuracy: 0.7031 - loss: 0.8191 - val_accuracy: 0.7350 - val_loss: 0.7626
# > Finalna dokładność: 0.735

# %%
def plot_history(history):
    plt.figure(figsize=(12, 4))

    # Wykres dokładności
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Trening')
    plt.plot(history.history['val_accuracy'], label='Test')
    plt.title('Dokładność modelu')
    plt.xlabel('Epoka')
    plt.ylabel('Accuracy')
    plt.legend()

    # Wykres straty
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Trening')
    plt.plot(history.history['val_loss'], label='Test')
    plt.title('Strata modelu')
    plt.xlabel('Epoka')
    plt.ylabel('Loss')
    plt.legend()

    plt.show()

plot_history(history)

# %%
y_pred = model.predict(testX)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = np.argmax(testY, axis=1)

classes = ['samolot', 'samochód', 'ptak', 'kot', 'jeleń', 'pies', 'żaba', 'koń', 'statek', 'ciężarówka']

plt.figure(figsize=(10, 8))
cm = confusion_matrix(y_true_classes, y_pred_classes)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=classes)
disp.plot(cmap=plt.cm.Blues, xticks_rotation='vertical')
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 32, 32, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 32, 32, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 16, 16, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 16, 16, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 8, 8, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 8, 8, 128)      │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       262,272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,101,142 (4.20 MB)
#  Trainable params: 550,570 (2.10 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 550,572 (2.10 MB)

# %%
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator # DODANE: import generatora

def prep_pixels(train, test):
    return train.astype('float32') / 255.0, test.astype('float32') / 255.0

def load_dataset():
    (trainX, trainY), (testX, testY) = cifar10.load_data()
    trainY = to_categorical(trainY)
    testY = to_categorical(testY)
    return trainX, trainY, testX, testY

trainX, trainY, testX, testY = load_dataset()
trainX, testX = prep_pixels(trainX, testX)

datagen = ImageDataGenerator(width_shift_range=0.1, height_shift_range=0.1, horizontal_flip=True)
it_train = datagen.flow(trainX, trainY, batch_size=64)
steps = int(trainX.shape[0] / 64)

model = tf.keras.models.load_model('final_model_sgd_argumentacja.keras')

# ZMIENIONE: Użycie generatora (it_train) i kroków (steps_per_epoch) zamiast surowych tablic trainX i trainY
history = model.fit(
    it_train,
    steps_per_epoch=steps,
    epochs=200,
    initial_epoch=100,
    validation_data=(testX, testY),
    verbose=1
)

model.save('final_model_sgd_argumentacja_200epok.keras')
# Out:
# Epoch 101/200
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 51s 57ms/step - accuracy: 0.7167 - loss: 0.8150 - val_accuracy: 0.7544 - val_loss: 0.6963
# Epoch 102/200
#   1/781 ━━━━━━━━━━━━━━━━━━━━ 10s 13ms/step - accuracy: 0.7031 - loss: 0.8369
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/epoch_iterator.py:116: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7031 - loss: 0.8369 - val_accuracy: 0.7528 - val_loss: 0.6998
# Epoch 103/200
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 32s 41ms/step - accuracy: 0.7188 - loss: 0.8092 - val_accuracy: 0.7558 - val_loss: 0.6975
# Epoch 104/200
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.
200
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8281 - loss: 0.4688 - val_accuracy: 0.8102 - val_loss: 0.5557

# %%
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout, BatchNormalization
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from matplotlib import pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import numpy as np
def plot_history(history):
    plt.figure(figsize=(12, 4))

    # Wykres dokładności
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Trening')
    plt.plot(history.history['val_accuracy'], label='Test')
    plt.title('Dokładność modelu')
    plt.xlabel('Epoka')
    plt.ylabel('Accuracy')
    plt.legend()

    # Wykres straty
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Trening')
    plt.plot(history.history['val_loss'], label='Test')
    plt.title('Strata modelu')
    plt.xlabel('Epoka')
    plt.ylabel('Loss')
    plt.legend()

    plt.show()

plot_history(history)

# %%
y_pred = model.predict(testX)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = np.argmax(testY, axis=1)

classes = ['samolot', 'samochód', 'ptak', 'kot', 'jeleń', 'pies', 'żaba', 'koń', 'statek', 'ciężarówka']

plt.figure(figsize=(10, 8))
cm = confusion_matrix(y_true_classes, y_pred_classes)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=classes)
disp.plot(cmap=plt.cm.Blues, xticks_rotation='vertical')
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step

# %%
model.summary()
# Opcjonalnie zapisz obrazek (może wymagać zainstalowania pydot):
# tf.keras.utils.plot_model(model, to_file='architektura.png', show_shapes=True)
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_18 (Conv2D)              │ (None, 32, 32, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_19 (Conv2D)              │ (None, 32, 32, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_9 (MaxPooling2D)  │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_12 (Dropout)            │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_20 (Conv2D)              │ (None, 16, 16, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_21 (Conv2D)              │ (None, 16, 16, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_10 (MaxPooling2D) │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_13 (Dropout)            │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_22 (Conv2D)              │ (None, 8, 8, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_23 (Conv2D)              │ (None, 8, 8, 128)      │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_11 (MaxPooling2D) │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_14 (Dropout)            │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_3 (Flatten)             │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 128)            │       262,272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_15 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,101,142 (4.20 MB)
#  Trainable params: 550,570 (2.10 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 550,572 (2.10 MB)

# %%
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator # DODANE: import generatora

def prep_pixels(train, test):
    return train.astype('float32') / 255.0, test.astype('float32') / 255.0

def load_dataset():
    (trainX, trainY), (testX, testY) = cifar10.load_data()
    trainY = to_categorical(trainY)
    testY = to_categorical(testY)
    return trainX, trainY, testX, testY

trainX, trainY, testX, testY = load_dataset()
trainX, testX = prep_pixels(trainX, testX)

datagen = ImageDataGenerator(width_shift_range=0.1, height_shift_range=0.1, horizontal_flip=True)
it_train = datagen.flow(trainX, trainY, batch_size=64)
steps = int(trainX.shape[0] / 64)

model = tf.keras.models.load_model('final_model_argumentacja.keras')

history = model.fit(
    it_train,
    steps_per_epoch=steps,
    epochs=200,
    initial_epoch=100,
    validation_data=(testX, testY),
    verbose=1
)

model.save('final_model_argumentacja_200epok.keras')
# Out:
# Epoch 101/200
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 44s 49ms/step - accuracy: 0.7912 - loss: 0.6244 - val_accuracy: 0.8165 - val_loss: 0.5726
# Epoch 102/200
#   1/781 ━━━━━━━━━━━━━━━━━━━━ 10s 13ms/step - accuracy: 0.8125 - loss: 0.6539
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/epoch_iterator.py:116: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8125 - loss: 0.6539 - val_accuracy: 0.8166 - val_loss: 0.5728
# Epoch 103/200
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 32s 41ms/step - accuracy: 0.7917 - loss: 0.6218 - val_accuracy: 0.8299 - val_loss: 0.5286
# Epoch 104/200
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7656 - loss: 0.6573 - val_accuracy: 0.8298 - val_loss: 0.5274
# Epoch 105/200
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 33s 42ms/step - accuracy: 0.7904 - loss: 0.6303 - val_accuracy: 0.8011 - val_loss: 0.6072
# Epoch 106/200
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8125 - loss: 0.5394 - val_accuracy: 0.8045 - val_loss: 0.5987
# Epoch 107/200
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 32s 41ms/step - accuracy: 0.7881 - loss: 0.6294 - val_accuracy: 0.7955 - val_loss: 0.6296
# Epoch 108/200
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8438 - loss: 0.5446 - val_accuracy: 0.7938 - val_loss: 0.6349
# Epoch 109/200
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 32s 40ms/step - accuracy: 0.7886 - loss: 0.6278 - val_accuracy: 0.8018 - val_loss: 0.6209
# Epoch 110/200
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8125 - loss: 0.6296 - val_accuracy: 0.7983 - val_loss: 0.6353
# Epoch 111/200
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 34s 43ms/step - accuracy: 0.7915 - loss: 0.6249 - val_accuracy: 0.8270 - val_loss: 0.5397
# Epoch 112/200
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8906 - loss: 0.4018 - val_accuracy: 0.8257 - val_loss: 0.5430
# Epoch 113/200
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 31s 40ms/step - accuracy: 0.7913 - loss: 0.6213 - val_accuracy: 0.8161 - val_loss: 0.5698
# Epoch 114/200
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8125 - loss: 0.6222 - val_accuracy: 0.8158 - val_loss: 0.5699
# Epoch 115/200
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 31s 40ms/step - accuracy: 0.7899 - loss: 0.6232 - val_accuracy: 0.8149 - val_loss: 0.5909
# Epoch 116/200
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8438 - loss: 0.4755 - val_accuracy: 0.8187 - val_loss: 0.5820
# Epoch 117/200
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 32s 41ms/step - accuracy: 0.7923 - loss: 0.6253 - val_accuracy: 0.8066 - val_loss: 0.6270
# Epoch 118/200
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8750 - loss: 0.4712 - val_accuracy: 0.8028 - val_loss: 0.6381
# Epoch 119/200
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 32s 41ms/step - accuracy: 0.
200
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 31s 40ms/step - accuracy: 0.8003 - loss: 0.5999 - val_accuracy: 0.8227 - val_loss: 0.5465
# Epoch 184/200
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7656 - loss: 0.4863 - val_accuracy: 0.8220 - val_loss: 0.5475
# Epoch 185/200
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 41s 41ms/step - accuracy: 0.8040 - loss: 0.5900 - val_accuracy: 0.8245 - val_loss: 0.5446
# Epoch 186/200
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8281 - loss: 0.5964 - val_accuracy: 0.8242 - val_loss: 0.5430
# Epoch 187/200
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 32s 41ms/step - accuracy: 0.8030 - loss: 0.5907 - val_accuracy: 0.8249 - val_loss: 0.5601
# Epoch 188/200
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8594 - loss: 0.5113 - val_accuracy: 0.8253 - val_loss: 0.5558
# Epoch 189/200
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 32s 41ms/step - accuracy: 0.7994 - loss: 0.6011 - val_accuracy: 0.8284 - val_loss: 0.5214
# Epoch 190/200
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7656 - loss: 0.7010 - val_accuracy: 0.8298 - val_loss: 0.5223
# Epoch 191/200
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 31s 40ms/step - accuracy: 0.8012 - loss: 0.5980 - val_accuracy: 0.8181 - val_loss: 0.5859
# Epoch 192/200
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8281 - loss: 0.4766 - val_accuracy: 0.8192 - val_loss: 0.5787
# Epoch 193/200
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 31s 40ms/step - accuracy: 0.8037 - loss: 0.5915 - val_accuracy: 0.8171 - val_loss: 0.5773
# Epoch 194/200
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7031 - loss: 0.6975 - val_accuracy: 0.8187 - val_loss: 0.5662
# Epoch 195/200
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 31s 40ms/step - accuracy: 0.8020 - loss: 0.5981 - val_accuracy: 0.8261 - val_loss: 0.5388
# Epoch 196/200
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7656 - loss: 0.6971 - val_accuracy: 0.8305 - val_loss: 0.5295
# Epoch 197/200
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 31s 40ms/step - accuracy: 0.8031 - loss: 0.5883 - val_accuracy: 0.8080 - val_loss: 0.6306
# Epoch 198/200
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8438 - loss: 0.4270 - val_accuracy: 0.8060 - val_loss: 0.6372
# Epoch 199/200
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 31s 39ms/step - accuracy: 0.8021 - loss: 0.5950 - val_accuracy: 0.8216 - val_loss: 0.5631
# Epoch 200/200
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7656 - loss: 0.5910 - val_accuracy: 0.8213 - val_loss: 0.5638

# %%
def plot_history(history):
    plt.figure(figsize=(12, 4))

    # Wykres dokładności
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Trening')
    plt.plot(history.history['val_accuracy'], label='Test')
    plt.title('Dokładność modelu')
    plt.xlabel('Epoka')
    plt.ylabel('Accuracy')
    plt.legend()

    # Wykres straty
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Trening')
    plt.plot(history.history['val_loss'], label='Test')
    plt.title('Strata modelu')
    plt.xlabel('Epoka')
    plt.ylabel('Loss')
    plt.legend()

    plt.show()

plot_history(history)

# %%
y_pred = model.predict(testX)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = np.argmax(testY, axis=1)

classes = ['samolot', 'samochód', 'ptak', 'kot', 'jeleń', 'pies', 'żaba', 'koń', 'statek', 'ciężarówka']

plt.figure(figsize=(10, 8))
cm = confusion_matrix(y_true_classes, y_pred_classes)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=classes)
disp.plot(cmap=plt.cm.Blues, xticks_rotation='vertical')
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step

# %%
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_12 (Conv2D)              │ (None, 32, 32, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_13 (Conv2D)              │ (None, 32, 32, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_6 (MaxPooling2D)  │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_14 (Conv2D)              │ (None, 16, 16, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_15 (Conv2D)              │ (None, 16, 16, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_7 (MaxPooling2D)  │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_16 (Conv2D)              │ (None, 8, 8, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_17 (Conv2D)              │ (None, 8, 8, 128)      │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_8 (MaxPooling2D)  │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_2 (Flatten)             │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 128)            │       262,272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,651,712 (6.30 MB)
#  Trainable params: 550,570 (2.10 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 1,101,142 (4.20 MB)

# %% [markdown]
# ### **Ulepszona wersja modelu z Batch Normalization, Early Stopping i Model Checkpoint**
#
# Bazując na powyższych sugestiach, przedstawię teraz zaktualizowany kod, który zawiera warstwy Batch Normalization w architekturze oraz callbacki `EarlyStopping` i `ModelCheckpoint` w procesie treningu. Poprawiono również obliczanie `steps_per_epoch`.
#
# **Zalety tych zmian:**
# *   **Batch Normalization**: Zwiększa stabilność i szybkość treningu, a także może poprawić dokładność.
# *   **Early Stopping**: Zapobiega overfittingowi, zatrzymując trening, gdy model nie poprawia się na zbiorze walidacyjnym.
# *   **Model Checkpoint**: Zapisuje najlepszą wersję modelu w trakcie treningu, co jest szczególnie przydatne, gdy `EarlyStopping` zatrzymuje trening przed końcem wszystkich epok.
# *   **Poprawiony `steps_per_epoch`**: Zapewnia, że generator danych przetwarza wszystkie próbki treningowe w każdej epoce, eliminując ostrzeżenie `Your input ran out of data`.

# %%
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout, BatchNormalization # Dodano BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from matplotlib import pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import numpy as np
import math # Dodano import math dla ceil

def load_dataset():
    (trainX, trainY), (testX, testY) = cifar10.load_data()
    trainY = to_categorical(trainY)
    testY = to_categorical(testY)
    return trainX, trainY, testX, testY

def prep_pixels(train, test):
    return train.astype('float32') / 255.0, test.astype('float32') / 255.0

def define_model_improved():
    model = Sequential()

    init = 'he_uniform'

    # Blok 1
    model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer=init, padding='same', input_shape=(32, 32, 3)))
    model.add(BatchNormalization()) # Dodano BatchNormalization
    model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer=init, padding='same'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D((2, 2)))
    model.add(Dropout(0.2))

    # Blok 2
    model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer=init, padding='same'))
    model.add(BatchNormalization())
    model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer=init, padding='same'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D((2, 2)))
    model.add(Dropout(0.3))

    # Blok 3
    model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer=init, padding='same'))
    model.add(BatchNormalization())
    model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer=init, padding='same'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D((2, 2)))
    model.add(Dropout(0.4))

    # Klasyfikator
    model.add(Flatten())
    model.add(Dense(128, activation='relu', kernel_initializer=init))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))
    model.add(Dense(10, activation='softmax'))

    model.compile(optimizer=Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# Zaktualizowana funkcja run_test_harness z callbackami
def run_test_harness_improved():
    trainX, trainY, testX, testY = load_dataset()
    trainX, testX = prep_pixels(trainX, testX)

    model = define_model_improved()

    # Tworzenie generatora danych (augmentacja)
    datagen = ImageDataGenerator(width_shift_range=0.1, height_shift_range=0.1, horizontal_flip=True)
    it_train = datagen.flow(trainX, trainY, batch_size=64)

    # Poprawione obliczanie steps_per_epoch
    steps_per_epoch = math.ceil(trainX.shape[0] / 64)

    # Callbacki
    # EarlyStopping: zatrzyma trening, jeśli val_accuracy nie poprawi się przez 20 epok
    es = EarlyStopping(monitor='val_accuracy', mode='max', patience=20, verbose=1)
    # ModelCheckpoint: zapisze najlepszy model na podstawie val_accuracy
    mc = ModelCheckpoint('best_model_improved.keras', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)

    # Trenowanie modelu z augmentacją i callbackami
    print("\nRozpoczynam trening ulepszonego modelu...")
    history = model.fit(
        it_train,
        steps_per_epoch=steps_per_epoch,
        epochs=100, # Ustawiamy na 100 epok, ale EarlyStopping może zatrzymać wcześniej
        validation_data=(testX, testY),
        verbose=1,
        callbacks=[es, mc] # Dodano callbacki
    )

    # Wczytanie najlepszego zapisanego modelu do oceny
    print("\nŁadowanie najlepszego modelu do oceny...")
    saved_model = tf.keras.models.load_model('best_model_improved.keras')

    # Ocena modelu
    _, acc = saved_model.evaluate(testX, testY, verbose=0)
    print(f'> Finalna dokładność najlepszego modelu: {acc:.3f}')

    return saved_model, history, testX, testY

# Wywołanie ulepszonego test harness
model_improved, history_improved, testX_improved, testY_improved = run_test_harness_improved()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Rozpoczynam trening ulepszonego modelu...
# Epoch 1/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.3194 - loss: 2.1107
# Epoch 1: val_accuracy improved from None to 0.50920, saving model to best_model_improved.keras
#
# Epoch 1: finished saving model to best_model_improved.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 62s 58ms/step - accuracy: 0.4016 - loss: 1.7316 - val_accuracy: 0.5092 - val_loss: 1.3768
# Epoch 2/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.5414 - loss: 1.2856
# Epoch 2: val_accuracy improved from 0.50920 to 0.61990, saving model to best_model_improved.keras
#
# Epoch 2: finished saving model to best_model_improved.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 48s 62ms/step - accuracy: 0.5577 - loss: 1.2378 - val_accuracy: 0.6199 - val_loss: 1.0842
# Epoch 3/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.6142 - loss: 1.0870
# Epoch 3: val_accuracy improved from 0.61990 to 0.67360, saving model to best_model_improved.keras
#
# Epoch 3: finished saving model to best_model_improved.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 37s 47ms/step - accuracy: 0.6277 - loss: 1.0589 - val_accuracy: 0.6736 - val_loss: 0.9386
# Epoch 4/100
# 781/782 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.6689 - loss: 0.9581
# Epoch 4: val_accuracy improved from 0.67360 to 0.68170, saving model to best_model_improved.keras
#
# Epoch 4: finished saving model to best_model_improved.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 36s 47ms/step - accuracy: 0.6709 - loss: 0.9472 - val_accuracy: 0.6817 - val_loss: 0.9161
# Epoch 5/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.6917 - loss: 0.8839
# Epoch 5: val_accuracy improved from 0.68170 to 0.75760, saving model to best_model_improved.keras
#
# Epoch 5: finished saving model to best_model_improved.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 48s 61ms/step - accuracy: 0.6962 - loss: 0.8694 - val_accuracy: 0.7576 - val_loss: 0.7002
# Epoch 6/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.7111 - loss: 0.8347
# Epoch 6: val_accuracy did not improve from 0.75760
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 34s 44ms/step - accuracy: 0.7179 - loss: 0.8151 - val_accuracy: 0.7462 - val_loss: 0.7475
# Epoch 7/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.7333 - loss: 0.7621
# Epoch 7: val_accuracy did not improve from 0.75760
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 35s 45ms/step - accuracy: 0.7351 - loss: 0.7627 - val_accuracy: 0.7508 - val_loss: 0.7429
# Epoch 8/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.7468 - loss: 0.7350
# Epoch 8: val_accuracy improved from 0.75760 to 0.78320, saving model to best_model_improved.keras
#
# Epoch 8: finished saving model to best_model_improved.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 41s 52ms/step - accuracy: 0.7523 - loss: 0.7237 - val_accuracy: 0.7832 - val_loss: 0.6274
# Epoch 9/100
# 781/782 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.7604 - loss: 0.6956
# Epoch 9: val_accuracy improved from 0.78320 to 0.79550, saving model to best_model_improved.keras
#
# Epoch 9: finished saving model to best_model_improved.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 38s 49ms/step - accuracy: 0.7635 - loss: 0.6860 - val_accuracy: 0.7955 - val_loss: 0.6011
# Epoch 10/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.7750 - loss: 0.6604
# Epoch 10: val_accuracy did not improve from 0.79550
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 39s 49ms/step - accuracy: 0.7758 - loss: 0.6617 - val_accuracy: 0.7812 - val_loss: 0.6514
# Epoch 11/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.7798 - loss: 0.6402
# Epoch 11: val_accuracy did not improve from 0.79550
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 38s 46ms/step - accuracy: 0.7842 - loss: 0.6326 - val_accuracy: 0.7888 - val_loss: 0.6326
# Epoch 12/100
# 781/782 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.7920 - loss: 0.6082
# Epoch 12: val_accuracy improved from 0.79550 to 0.80300, saving model to best_model_improved.keras
#
# Epoch 12: finished saving model to best_model_improved.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 47s 60ms/step - accuracy: 0.7918 - loss: 0.6099 - val_accuracy: 0.8030 - val_loss: 0.5799
# Epoch 13/100
# 781/782 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.7974 - loss: 0.5947
# Epoch 13: val_accuracy improved from 0.80300 to 0.81920, saving model to best_model_improved.keras
#
# Epoch 13: finished saving model to best_model_improved.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 36s 46ms/step - accuracy: 0.7975 - loss: 0.5958 - val_accuracy: 0.8192 - val_loss: 0.5356
# Epoch 14/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.8043 - loss: 0.5716
# Epoch 14: val_accuracy improved from 0.81920 to 0.82970, saving model to best_model_improved.keras
#
# Epoch 14: finished saving model to best_model_improved.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 35s 44ms/step - accuracy: 0.8042 - loss: 0.5754 - val_accuracy: 0.8297 - val_loss: 0.5055
# Epoch 15/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8088 - loss: 0.5627
# Epoch 15: val_accuracy did not improve from 0.82970
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 37s 47ms/step - accuracy: 0.8071 - loss: 0.5672 - val_accuracy: 0.8247 - val_loss: 0.5192
# Epoch 16/100
# 781/782 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.8114 - loss: 0.5601
# Epoch 16: val_accuracy did not improve from 0.82970
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 37s 47ms/step - accuracy: 0.8114 - loss: 0.5573 - val_accuracy: 0.8119 - val_loss: 0.5684
# Epoch 17/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8174 - loss: 0.5409
# Epoch 17: val_accuracy did not improve from 0.82970
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 36s 46ms/step - accuracy: 0.8169 - loss: 0.5413 - val_accuracy: 0.8187 - val_loss: 0.5285
# Epoch 18/100
# 781/782 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.8226 - loss: 0.5217
# Epoch 18: val_accuracy did not improve from 0.82970
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 36s 46ms/step - accuracy: 0.8210 - loss: 0.5271 - val_accuracy: 0.8142 - val_loss: 0.5744
# Epoch 19/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.8315 - loss: 0.5042
# Epoch 19: val_accuracy improved from 0.82970 to 0.83450, saving model to best_model_improved.keras
#
# Epoch 19: finished saving model to best_model_improved.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 35s 44ms/step - accuracy: 0.8283 - loss: 0.5120 - val_accuracy: 0.8345 - val_loss: 0.4966
# Epoch 20/100
# 781/782 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8255 - loss: 0.5139
# Epoch 20: val_accuracy improved from 0.83450 to 0.83880, saving model to best_model_improved.keras
#
# Epoch 20: finished saving model to best_model_improved.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 36s 46ms/step - accuracy: 0.8253 - loss: 0.5118 - val_accuracy: 0.8388 - val_loss: 0.4744
# Epoch 21/100
# 781/782 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8303 - loss: 0.4979
# Epoch 21: val_accuracy improved from 0.83880 to 0.84490, saving model to best_model_improved.keras
#
# Epoch 21: finished saving model to best_model_improved.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 36s 46ms/step - accuracy: 0.8309 - loss: 0.4964 - val_accuracy: 0.8449 - val_loss: 0.4695
# Epoch 22/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8308 - loss: 0.4946
# Epoch 22: val_accuracy did not improve from 0.84490
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 35s 44ms/step - accuracy: 0.8326 - loss: 0.4939 - val_accuracy: 0.8429 - val_loss: 0.4740
# Epoch 23/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8391 - loss: 0.4738
# Epoch 23: val_accuracy did not improve from 0.84490
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 34s 43ms/step - accuracy: 0.8348 - loss: 0.4878 - val_accuracy: 0.8099 - val_loss: 0.5703
# Epoch 24/100
# 781/782 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8393 - loss: 0.4711
# Epoch 24: val_accuracy improved from 0.84490 to 0.85110, saving model to best_model_improved.keras
#
# Epoch 24: finished saving model to best_model_improved.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 36s 45ms/step - accuracy: 0.8389 - loss: 0.4757 - val_accuracy: 0.8511 - val_loss: 0.4402
# Epoch 25/100
# 781/782 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.8429 - loss: 0.4664
# Epoch 25: val_accuracy did not improve from 0.85110
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 35s 44ms/step - accuracy: 0.8406 - loss: 0.4690 - val_accuracy: 0.8320 - val_loss: 0.5019
# Epoch 26/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8428 - loss: 0.4602
# Epoch 26: val_accuracy improved from 0.85110 to 0.85290, saving model to best_model_improved.keras
#
# Epoch 26: finished saving model to best_model_improved.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 34s 44ms/step - accuracy: 0.8434 - loss: 0.4596 - val_accuracy: 0.8529 - val_loss: 0.4451
# Epoch 27/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.8472 - loss: 0.4547
# Epoch 27: val_accuracy did not improve from 0.85290
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 35s 45ms/step - accuracy: 0.8468 - loss: 0.4551 - val_accuracy: 0.8424 - val_loss: 0.4781
# Epoch 28/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.8482 - loss: 0.4442
# Epoch 28: val_accuracy improved from 0.85290 to 0.86070, saving model to best_model_improved.keras
#
# Epoch 28: finished saving model to best_model_improved.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 41s 45ms/step - accuracy: 0.8483 - loss: 0.4476 - val_accuracy: 0.8607 - val_loss: 0.4266
# Epoch 29/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8517 - loss: 0.4340
# Epoch 29: val_accuracy did not improve from 0.86070
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 42s 45ms/step - accuracy: 0.8491 - loss: 0.4420 - val_accuracy: 0.8493 - val_loss: 0.4654
# Epoch 30/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8543 - loss: 0.4383
# Epoch 30: val_accuracy improved from 0.86070 to 0.86350, saving model to best_model_improved.keras
#
# Epoch 30: finished saving model to best_model_improved.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 34s 44ms/step - accuracy: 0.8513 - loss: 0.4449 - val_accuracy: 0.8635 - val_loss: 0.4146
# Epoch 31/100
# 781/782 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8529 - loss: 0.4328
# Epoch 31: val_accuracy did not improve from 0.86350
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 35s 45ms/step - accuracy: 0.8535 - loss: 0.4336 - val_accuracy: 0.8619 - val_loss: 0.4096
# Epoch 32/100
# 781/782 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8547 - loss: 0.4241
# Epoch 32: val_accuracy did not improve from 0.86350
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 36s 46ms/step - accuracy: 0.8524 - loss: 0.4310 - val_accuracy: 0.8581 - val_loss: 0.4355
# Epoch 33/100
# 781/782 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.8575 - loss: 0.4255
# Epoch 33: val_accuracy did not improve from 0.86350
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 41s 53ms/step - accuracy: 0.8553 - loss: 0.4283 - val_accuracy: 0.8556 - val_loss: 0.4374
# Epoch 34/100
# 781/782 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.8585 - loss: 0.4167
# Epoch 34: val_accuracy improved from 0.86350 to 0.87090, saving model to best_model_improved.keras
#
# Epoch 34: finished saving model to best_model_improved.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 87s 60ms/step - accuracy: 0.8567 - loss: 0.4230 - val_accuracy: 0.8709 - val_loss: 0.3841
# Epoch 35/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.8604 - loss: 0.4154
# Epoch 35: val_accuracy did not improve from 0.87090
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 35s 45ms/step - accuracy: 0.8583 - loss: 0.4200 - val_accuracy: 0.8517 - val_loss: 0.4463
# Epoch 36/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.8586 - loss: 0.4209
# Epoch 36: val_accuracy did not improve from 0.87090
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 35s 44ms/step - accuracy: 0.
# Epoch 96/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8980 - loss: 0.2991
# Epoch 96: val_accuracy did not improve from 0.89590
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 36s 46ms/step - accuracy: 0.8961 - loss: 0.3038 - val_accuracy: 0.8936 - val_loss: 0.3292
# Epoch 97/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8989 - loss: 0.2959
# Epoch 97: val_accuracy did not improve from 0.89590
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 36s 47ms/step - accuracy: 0.8968 - loss: 0.3024 - val_accuracy: 0.8854 - val_loss: 0.3496
# Epoch 98/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.8960 - loss: 0.2978
# Epoch 98: val_accuracy did not improve from 0.89590
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 37s 47ms/step - accuracy: 0.8960 - loss: 0.3010 - val_accuracy: 0.8918 - val_loss: 0.3252
# Epoch 99/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8967 - loss: 0.3043
# Epoch 99: val_accuracy did not improve from 0.89590
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 36s 46ms/step - accuracy: 0.8977 - loss: 0.2997 - val_accuracy: 0.8912 - val_loss: 0.3378
# Epoch 100/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8993 - loss: 0.2890
# Epoch 100: val_accuracy did not improve from 0.89590
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 36s 46ms/step - accuracy: 0.8983 - loss: 0.2966 - val_accuracy: 0.8928 - val_loss: 0.3210
#
# Ładowanie najlepszego modelu do oceny...
# > Finalna dokładność najlepszego modelu: 0.896

# %% [markdown]
# ### **Wizualizacja wyników ulepszonego modelu**

# %%
# Funkcja do rysowania historii (zdefiniowana tylko raz)
def plot_history(history):
    plt.figure(figsize=(12, 4))

    # Wykres dokładności
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Trening')
    plt.plot(history.history['val_accuracy'], label='Test')
    plt.title('Dokładność modelu')
    plt.xlabel('Epoka')
    plt.ylabel('Accuracy')
    plt.legend()

    # Wykres straty
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Trening')
    plt.plot(history.history['val_loss'], label='Test')
    plt.title('Strata modelu')
    plt.xlabel('Epoka')
    plt.ylabel('Loss')
    plt.legend()

    plt.show()

plot_history(history_improved)

# %%
y_pred_improved = model_improved.predict(testX_improved)
y_pred_classes_improved = np.argmax(y_pred_improved, axis=1)
y_true_classes_improved = np.argmax(testY_improved, axis=1)

classes = ['samolot', 'samochód', 'ptak', 'kot', 'jeleń', 'pies', 'żaba', 'koń', 'statek', 'ciężarówka']

plt.figure(figsize=(10, 8))
cm_improved = confusion_matrix(y_true_classes_improved, y_pred_classes_improved)
disp_improved = ConfusionMatrixDisplay(confusion_matrix=cm_improved, display_labels=classes)
disp_improved.plot(cmap=plt.cm.Blues, xticks_rotation='vertical')
plt.title('Macierz pomyłek ulepszonego modelu')
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step

# %%
print("Architektura ulepszonego modelu:")
model_improved.summary()

# Wizualizacja architektury sieciowej
tf.keras.utils.plot_model(
    model_improved,
    to_file='architektura_ulepszona.png', # Zmieniona nazwa pliku
    show_shapes=True,
    show_layer_names=True,
    dpi=70 # Zwiększ rozdzielczość dla lepszej czytelności
)
print("Zapisano wizualizację architektury modelu do pliku 'architektura_ulepszona.png'.")
# Out:
# Architektura ulepszonego modelu:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 32, 32, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 32, 32, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 32, 32, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 32, 32, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 16, 16, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 16, 16, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 16, 16, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 16, 16, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 8, 8, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 8, 8, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 8, 8, 128)      │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 8, 8, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       262,272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,656,320 (6.32 MB)
#  Trainable params: 551,722 (2.10 MB)
#  Non-trainable params: 1,152 (4.50 KB)
#  Optimizer params: 1,103,446 (4.21 MB)
# Zapisano wizualizację architektury modelu do pliku 'architektura_ulepszona.png'.

# %%
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint # DODANE: import callbacków
import math # DODANE: import math dla ceil

def prep_pixels(train, test):
    return train.astype('float32') / 255.0, test.astype('float32') / 255.0

def load_dataset():
    (trainX, trainY), (testX, testY) = cifar10.load_data()
    trainY = to_categorical(trainY)
    testY = to_categorical(testY)
    return trainX, trainY, testX, testY

trainX, trainY, testX, testY = load_dataset()
trainX, testX = prep_pixels(trainX, testX)

# DODANE: Odtworzenie generatora z pierwszego skryptu
datagen = ImageDataGenerator(width_shift_range=0.1, height_shift_range=0.1, horizontal_flip=True)
it_train = datagen.flow(trainX, trainY, batch_size=64)

# Poprawione obliczanie steps_per_epoch
steps_per_epoch = math.ceil(trainX.shape[0] / 64)

# Wczytanie zapisanego modelu
model = tf.keras.models.load_model('final_model_sgd_argumentacja_200epok.keras')

# Definiowanie callbacków
es = EarlyStopping(monitor='val_accuracy', mode='max', patience=20, verbose=1)
mc = ModelCheckpoint('final_model_sgd_argumentacja_extended_best.keras', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)

# ZMIENIONE: Użycie generatora (it_train) i kroków (steps_per_epoch) zamiast surowych tablic trainX i trainY
history = model.fit(
    it_train,
    steps_per_epoch=steps_per_epoch,
    epochs=300,
    initial_epoch=200,
    validation_data=(testX, testY),
    verbose=1,
    callbacks=[es, mc] # DODANE: Callbacki do treningu
)

# Wczytanie najlepszego zapisanego modelu do oceny
saved_model = tf.keras.models.load_model('final_model_sgd_argumentacja_extended_best.keras')

# Ocena modelu
_, acc = saved_model.evaluate(testX, testY, verbose=0)
print(f'> Finalna dokładność najlepszego modelu po kontynuacji: {acc:.3f}')
# Out:
# Epoch 201/300
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.7965 - loss: 0.6021
# Epoch 201: val_accuracy improved from None to 0.81670, saving model to final_model_sgd_argumentacja_extended_best.keras
#
# Epoch 201: finished saving model to final_model_sgd_argumentacja_extended_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 50s 54ms/step - accuracy: 0.8003 - loss: 0.5961 - val_accuracy: 0.8167 - val_loss: 0.5985
# Epoch 202/300
# 781/782 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.7996 - loss: 0.5900
# Epoch 202: val_accuracy improved from 0.81670 to 0.82790, saving model to final_model_sgd_argumentacja_extended_best.keras
#
# Epoch 202: finished saving model to final_model_sgd_argumentacja_extended_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 35s 44ms/step - accuracy: 0.8007 - loss: 0.5951 - val_accuracy: 0.8279 - val_loss: 0.5344
# Epoch 203/300
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.8028 - loss: 0.5928
# Epoch 203: val_accuracy improved from 0.82790 to 0.83830, saving model to final_model_sgd_argumentacja_extended_best.keras
#
# Epoch 203: finished saving model to final_model_sgd_argumentacja_extended_best.keras
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 35s 45ms/step - accuracy: 0.8015 - loss: 0.5959 - val_accuracy: 0.8383 - val_loss: 0.5010
# Epoch 204/300
# 781/782 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.8031 - loss: 0.5924
# Epoch 204: val_accuracy did not improve from 0.83830
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 35s 45ms/step - accuracy: 0.8016 - loss: 0.5963 - val_accuracy: 0.8306 - val_loss: 0.5533
# Epoch 205/300
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8047 - loss: 0.5855
# Epoch 205: val_accuracy did not improve from 0.83830
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 34s 44ms/step - accuracy: 0.8057 - loss: 0.5894 - val_accuracy: 0.8209 - val_loss: 0.5795
# Epoch 206/300
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8100 - loss: 0.5707
# Epoch 206: val_accuracy did not improve from 0.83830
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 36s 46ms/step - accuracy: 0.8059 - loss: 0.5867 - val_accuracy: 0.8317 - val_loss: 0.5458
# Epoch 207/300
# 781/782 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.8038 - loss: 0.5918
# Epoch 207: val_accuracy did not improve from 0.83830
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 34s 44ms/step - accuracy: 0.8022 - loss: 0.5976 - val_accuracy: 0.8258 - val_loss: 0.5522
# Epoch 208/300
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8040 - loss: 0.5853
# Epoch 208: val_accuracy did not improve from 0.83830
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 36s 46ms/step - accuracy: 0.8021 - loss: 0.5941 - val_accuracy: 0.8264 - val_loss: 0.5486
# Epoch 209/300
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8035 - loss: 0.5864
# Epoch 209: val_accuracy did not improve from 0.83830
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 42s 47ms/step - accuracy: 0.8025 - loss: 0.5942 - val_accuracy: 0.8211 - val_loss: 0.5721
# Epoch 210/300
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8056 - loss: 0.5849
# Epoch 210: val_accuracy did not improve from 0.83830
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 40s 45ms/step - accuracy: 0.8052 - loss: 0.5890 - val_accuracy: 0.8119 - val_loss: 0.6279
# Epoch 211/300
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8061 - loss: 0.5818
# Epoch 211: val_accuracy did not improve from 0.83830
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 36s 46ms/step - accuracy: 0.8030 - loss: 0.5930 - val_accuracy: 0.8209 - val_loss: 0.5714
# Epoch 212/300
# 781/782 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.8025 - loss: 0.5960
# Epoch 212: val_accuracy did not improve from 0.83830
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 35s 45ms/step - accuracy: 0.8057 - loss: 0.5906 - val_accuracy: 0.8247 - val_loss: 0.5861
# Epoch 213/300
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8049 - loss: 0.5868
# Epoch 213: val_accuracy did not improve from 0.83830
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 36s 46ms/step - accuracy: 0.8030 - loss: 0.5968 - val_accuracy: 0.8159 - val_loss: 0.5771
# Epoch 214/300
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.8048 - loss: 0.5836
# Epoch 214: val_accuracy did not improve from 0.83830
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 35s 45ms/step - accuracy: 0.8036 - loss: 0.5931 - val_accuracy: 0.7985 - val_loss: 0.6499
# Epoch 215/300
# 781/782 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8034 - loss: 0.5899
# Epoch 215: val_accuracy did not improve from 0.83830
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 37s 47ms/step - accuracy: 0.8049 - loss: 0.5904 - val_accuracy: 0.8315 - val_loss: 0.5600
# Epoch 216/300
# 781/782 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.8021 - loss: 0.5976
# Epoch 216: val_accuracy did not improve from 0.83830
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 35s 44ms/step - accuracy: 0.8030 - loss: 0.5959 - val_accuracy: 0.8303 - val_loss: 0.5466
# Epoch 217/300
# 781/782 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8049 - loss: 0.5989
# Epoch 217: val_accuracy did not improve from 0.83830
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 36s 46ms/step - accuracy: 0.8063 - loss: 0.5897 - val_accuracy: 0.7972 - val_loss: 0.6576
# Epoch 218/300
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.8056 - loss: 0.5891
# Epoch 218: val_accuracy did not improve from 0.83830
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 35s 45ms/step - accuracy: 0.8057 - loss: 0.5915 - val_accuracy: 0.8195 - val_loss: 0.5653
# Epoch 219/300
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8044 - loss: 0.5873
# Epoch 219: val_accuracy did not improve from 0.83830
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 36s 47ms/step - accuracy: 0.8027 - loss: 0.5941 - val_accuracy: 0.8154 - val_loss: 0.5852
# Epoch 220/300
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.8032 - loss: 0.5970
# Epoch 220: val_accuracy did not improve from 0.83830
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 35s 45ms/step - accuracy: 0.8042 - loss: 0.5910 - val_accuracy: 0.8033 - val_loss: 0.6173
# Epoch 221/300
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8026 - loss: 0.5982
# Epoch 221: val_accuracy did not improve from 0.83830
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 37s 47ms/step - accuracy: 0.8035 - loss: 0.5931 - val_accuracy: 0.8175 - val_loss: 0.5787
# Epoch 222/300
# 781/782 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8053 - loss: 0.5897
# Epoch 222: val_accuracy did not improve from 0.83830
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 35s 45ms/step - accuracy: 0.8034 - loss: 0.5940 - val_accuracy: 0.8029 - val_loss: 0.6161
# Epoch 223/300
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8010 - loss: 0.5993
# Epoch 223: val_accuracy did not improve from 0.83830
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 36s 46ms/step - accuracy: 0.8038 - loss: 0.5970 - val_accuracy: 0.8274 - val_loss: 0.5548
# Epoch 223: early stopping
# > Finalna dokładność najlepszego modelu po kontynuacji: 0.838

# %%
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout, BatchNormalization
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from matplotlib import pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import numpy as np
def plot_history(history):
    plt.figure(figsize=(12, 4))

    # Wykres dokładności
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Trening')
    plt.plot(history.history['val_accuracy'], label='Test')
    plt.title('Dokładność modelu')
    plt.xlabel('Epoka')
    plt.ylabel('Accuracy')
    plt.legend()

    # Wykres straty
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Trening')
    plt.plot(history.history['val_loss'], label='Test')
    plt.title('Strata modelu')
    plt.xlabel('Epoka')
    plt.ylabel('Loss')
    plt.legend()

    plt.show()

plot_history(history)

# %%
y_pred = model.predict(testX)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = np.argmax(testY, axis=1)

classes = ['samolot', 'samochód', 'ptak', 'kot', 'jeleń', 'pies', 'żaba', 'koń', 'statek', 'ciężarówka']

plt.figure(figsize=(10, 8))
cm = confusion_matrix(y_true_classes, y_pred_classes)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=classes)
disp.plot(cmap=plt.cm.Blues, xticks_rotation='vertical')
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step

# %%
model.summary()
# Opcjonalnie zapisz obrazek (może wymagać zainstalowania pydot):
# tf.keras.utils.plot_model(model, to_file='architektura.png', show_shapes=True)
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_12 (Conv2D)              │ (None, 32, 32, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_13 (Conv2D)              │ (None, 32, 32, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_6 (MaxPooling2D)  │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_14 (Conv2D)              │ (None, 16, 16, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_15 (Conv2D)              │ (None, 16, 16, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_7 (MaxPooling2D)  │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_16 (Conv2D)              │ (None, 8, 8, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_17 (Conv2D)              │ (None, 8, 8, 128)      │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_8 (MaxPooling2D)  │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_2 (Flatten)             │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 128)            │       262,272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,651,712 (6.30 MB)
#  Trainable params: 550,570 (2.10 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 1,101,142 (4.20 MB)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
model.save('/content/drive/MyDrive/Modele/final_model.keras')
model.save('/content/drive/MyDrive/Modele/final_model2.keras')
model.save('/content/drive/MyDrive/Modele/final_model_argumentacja.keras')
model.save('/content/drive/MyDrive/Modele/final_model_sgd_argumentacja.keras')
model.save('/content/drive/MyDrive/Modele/final_model_sgd_argumentacja_200epok.keras')
model.save('/content/drive/MyDrive/Modele/final_model_argumentacja_200epok.keras')
model.save('/content/drive/MyDrive/Modele/final_model_sgd_argumentacja_extended_best.keras')
